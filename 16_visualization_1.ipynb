# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Input
#line
xpoint = np.array([0,10])
ypoint = np.array([0,250])

# %%
#3. Output
#line
plt.title("Line between two variable: Cynthia")
plt.plot(xpoint, ypoint)


plt.show()
